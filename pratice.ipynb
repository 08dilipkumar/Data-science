# %%
import pandas as pd

df = pd.read_csv('data/Uber1.csv') 
df.head()
# Out:
#    Unnamed: 0  Request id Pickup point  Driver id          Status  \
# 0           0         619      Airport          1  Trip Completed
# 1           1         867      Airport          1  Trip Completed
# 2           2        1807         City          1  Trip Completed
# 3           3        2532      Airport          1  Trip Completed
# 4           4        3112         City          1  Trip Completed
#
#      Request timestamp  Request hour Request timeslot Request dayofweek  \
# 0  2016-07-11 11:51:00            11          Morning            Monday
# 1  2016-07-11 17:57:00            17          Evening            Monday
# 2  2016-07-12 09:17:00             9          Morning           Tuesday
# 3  2016-07-12 21:08:00            21            Night           Tuesday
# 4  2016-07-13 08:33:16             8          Morning         Wednesday
#
#    TripComp  NoCars  Cancel  demand  supply  gap Supply demand gap
# 0       1.0     NaN     NaN       1     1.0  NaN            Supply
# ...
